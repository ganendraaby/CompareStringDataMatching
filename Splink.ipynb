# %%
pip install splink duckdb
# Out:
# Collecting splink
#   Downloading splink-4.0.8-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: duckdb in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: Jinja2>=3.0.3 in /usr/local/lib/python3.11/dist-packages (from splink) (3.1.6)
# Requirement already satisfied: altair>=5.0.1 in /usr/local/lib/python3.11/dist-packages (from splink) (5.5.0)
# Collecting igraph>=0.11.2 (from splink)
#   Downloading igraph-0.11.9-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: jsonschema>=3.2 in /usr/local/lib/python3.11/dist-packages (from splink) (4.24.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.11/dist-packages (from splink) (2.0.2)
# Requirement already satisfied: pandas>1.3.5 in /usr/local/lib/python3.11/dist-packages (from splink) (2.2.2)
# Requirement already satisfied: sqlglot>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from splink) (25.20.2)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair>=5.0.1->splink) (1.43.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from altair>=5.0.1->splink) (24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from altair>=5.0.1->splink) (4.14.0)
# Collecting texttable>=1.6.2 (from igraph>=0.11.2->splink)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.0.3->splink) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.2->splink) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.2->splink) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.2->splink) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.2->splink) (0.25.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>1.3.5->splink) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>1.3.5->splink) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>1.3.5->splink) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>1.3.5->splink) (1.17.0)
# Downloading splink-4.0.8-py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 46.8 MB/s eta 0:00:00
# Downloading igraph-0.11.9-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 117.5 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph, splink
# Successfully installed igraph-0.11.9 splink-4.0.8 texttable-1.7.0

# %%
import pandas as pd
from splink import Linker, SettingsCreator, block_on, DuckDBAPI
from splink.comparison_library import ExactMatch, JaroWinklerAtThresholds
from splink.blocking_rule_library import CustomRule

# 1. Muat dataset
df = pd.read_csv("clean_popcite.csv")
df
# Out:
#                                               Authors  \
# 0                        I Lewaa, MS Hafez, MA Ismail
# 1          M El Abassi, M Amnai, A Choukri, Y Fakhri…
# 2                     J Yang, K Xian, P Wang, Y Zhang
# 3                             J Yang, S Quan, P Wang…
# 4                                       Y Zhu, J Yang
# ..                                                ...
# 92  S Auzoux, B Ngaba, M Christina, B Heuclin, M R...
# 93                                A Coppens, V Maquil
# 94                 A Kato, H Wakabayashi, M Bradford…
# 95                      UV Albrecht, D Lawin, S Kuhn…
# 96                                            DA Wood
#
#                                                 Title  \
# 0   Data integration using statistical matching te...
# 1   Matching data detection for the integration sy...
# 2   A performance evaluation of correspondence gro...
# 3   Evaluating local geometric feature representat...
# 4   Automatic data matching for geospatial models:...
# ..                                                ...
# 92  Experimental variables in sugarcane intercropp...
# 93  Skeletal Data Matching and Merging from Multip...
# 94  Accurate ground positioning obtained from 3d d...
# 95  Time bias awareness in ECG-Based multiple sour...
# 96  Solar plus wind country-wide electrical power ...
#
#                                                Source
# 0                     Statistical Journal of the IAOS
# 1                          International Journal of …
# 2                      IEEE transactions on pattern …
# 3                              IEEE Transactions on …
# 4                                       Annals of GIS
# ..                                                ...
# 92                                      Data in Brief
# 93         … 2024, Valencia, Spain, September 15–18 …
# 94                                 IGARSS 2019-2019 …
# 95                          Advances in Informatics …
# 96  International Journal of Energy and Environmen...
#
# [97 rows x 3 columns]

# %%
# prompt: i want to make identifier based on index on df

# Assuming 'df' is your DataFrame from the previous cell
df['unique_id'] = (df.index + 1)
df
# Out:
#                                               Authors  \
# 0                        I Lewaa, MS Hafez, MA Ismail
# 1          M El Abassi, M Amnai, A Choukri, Y Fakhri…
# 2                     J Yang, K Xian, P Wang, Y Zhang
# 3                             J Yang, S Quan, P Wang…
# 4                                       Y Zhu, J Yang
# ..                                                ...
# 92  S Auzoux, B Ngaba, M Christina, B Heuclin, M R...
# 93                                A Coppens, V Maquil
# 94                 A Kato, H Wakabayashi, M Bradford…
# 95                      UV Albrecht, D Lawin, S Kuhn…
# 96                                            DA Wood
#
#                                                 Title  \
# 0   Data integration using statistical matching te...
# 1   Matching data detection for the integration sy...
# 2   A performance evaluation of correspondence gro...
# 3   Evaluating local geometric feature representat...
# 4   Automatic data matching for geospatial models:...
# ..                                                ...
# 92  Experimental variables in sugarcane intercropp...
# 93  Skeletal Data Matching and Merging from Multip...
# 94  Accurate ground positioning obtained from 3d d...
# 95  Time bias awareness in ECG-Based multiple sour...
# 96  Solar plus wind country-wide electrical power ...
#
#                                                Source  unique_id
# 0                     Statistical Journal of the IAOS          1
# 1                          International Journal of …          2
# 2                      IEEE transactions on pattern …          3
# 3                              IEEE Transactions on …          4
# 4                                       Annals of GIS          5
# ..                                                ...        ...
# 92                                      Data in Brief         93
# 93         … 2024, Valencia, Spain, September 15–18 …         94
# 94                                 IGARSS 2019-2019 …         95
# 95                          Advances in Informatics …         96
# 96  International Journal of Energy and Environmen...         97
#
# [97 rows x 4 columns]

# %%
# 2. Bangun daftar ComparisonCreator secara dinamis
comparisons = []
for col in ["Authors", "Title", "Source"]:
    # Satu comparison dengan tiga level: exact, ≥0.85, else
    comparisons.append(
        JaroWinklerAtThresholds(
            col_name=col,
            score_threshold_or_thresholds=[0.85]
        )
    )

# Untuk unique_id, gunakan ExactMatch saja
comparisons.append( ExactMatch(col_name="unique_id") )

# %%
# 3. Inisialisasi SettingsCreator dengan semua comparisons sekaligus
full_block = CustomRule("1 = 1")
settings = SettingsCreator(
    link_type="dedupe_only",
    comparisons=comparisons,
    blocking_rules_to_generate_predictions=[full_block]
)

# %%
# 4. Inisialisasi Linker dengan backend DuckDB
linker = Linker(
    df,
    settings,
    db_api=DuckDBAPI()
)

# %%
# 5. Pelatihan EM pada semua pasangan
linker.training.estimate_u_using_random_sampling(max_pairs=1e6, seed=42)
em_session = linker.training.estimate_parameters_using_expectation_maximisation(
    full_block,
    estimate_without_term_frequencies=False,
    fix_u_probabilities=False
)
# Out:
# WARNING:splink.internals.linker_components.training:You are using the default value for `max_pairs`, which may be too small and thus lead to inaccurate estimates for your model's u-parameters. Consider increasing to 1e8 or 1e9, which will result in more accurate estimates, but with a longer run time.
# INFO:splink.internals.estimate_u:----- Estimating u probabilities using random sampling -----
# INFO:splink.internals.m_u_records_to_parameters:u probability not trained for Title - Exact match on Title (comparison vector value: 2). This usually means the comparison level was never observed in the training data.
# INFO:splink.internals.m_u_records_to_parameters:u probability not trained for unique_id - Exact match on unique_id (comparison vector value: 1). This usually means the comparison level was never observed in the training data.
# INFO:splink.internals.estimate_u:
# Estimated u probabilities using random sampling
# INFO:splink.internals.settings:
# Your model is not yet fully trained. Missing estimates for:
#     - Authors (no m values are trained).
#     - Title (some u values are not trained, no m values are trained).
#     - Source (no m values are trained).
#     - unique_id (some u values are not trained, no m values are trained).
# INFO:splink.internals.em_training_session:
# ----- Starting EM training session -----
#
# INFO:splink.internals.em_training_session:Estimating the m and u probabilities of the model by blocking on:
# 1 = 1
#
# Parameter estimates will be made for the following comparison(s):
#     - Authors
#     - Title
#     - Source
#     - unique_id
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
# INFO:splink.internals.expectation_maximisation:
# WARNING:splink.internals.expectation_maximisation:WARNING:
# Level Exact match on Title on comparison Title not observed in dataset, unable to train m value
#
# WARNING:splink.internals.expectation_maximisation:WARNING:
# Level Exact match on Title on comparison Title not observed in dataset, unable to train u value
#
# WARNING:splink.internals.expectation_maximisation:WARNING:
# Level Exact match on unique_id on comparison unique_id not observed in dataset, unable to train m value
#
# WARNING:splink.internals.expectation_maximisation:WARNING:
# Level Exact match on unique_id on comparison unique_id not observed in dataset, unable to train u value
#
# INFO:splink.internals.expectation_maximisation:Iteration 1: Largest change in params was 0.966 in the m_probability of Title, level `Jaro-Winkler distance of Title >= 0.85`
# INFO:splink.internals.expectation_maximisation:Iteration 2: Largest change in params was 0.109 in the m_probability of Authors, level `Jaro-Winkler distance of Authors >= 0.85`
# INFO:splink.internals.expectation_maximisation:Iteration 3: Largest change in params was 0.037 in the m_probability of Title, level `All other comparisons`
# INFO:splink.internals.expectation_maximisation:Iteration 4: Largest change in params was -0.323 in the m_probability of Title, level `Jaro-Winkler distance of Title >= 0.85`
# INFO:splink.internals.expectation_maximisation:Iteration 5: Largest change in params was -0.128 in the m_probability of Title, level `Jaro-Winkler distance of Title >= 0.85`
# INFO:splink.internals.expectation_maximisation:Iteration 6: Largest change in params was 0.00538 in the m_probability of Title, level `All other comparisons`
# INFO:splink.internals.expectation_maximisation:Iteration 7: Largest change in params was -0.000182 in the m_probability of Title, level `Jaro-Winkler distance of Title >= 0.85`
# INFO:splink.internals.expectation_maximisation:Iteration 8: Largest change in params was 4.8e-05 in the m_probability of Authors, level `Exact match on Authors`
# INFO:splink.internals.expectation_maximisation:
# EM converged after 8 iterations
# INFO:splink.internals.em_training_session:m probability not trained for Title - Exact match on Title (comparison vector value: 2). This usually means the comparison level was never observed in the training data.
# INFO:splink.internals.em_training_session:u probability not trained for Title - Exact match on Title (comparison vector value: 2). This usually means the comparison level was never observed in the training data.
# INFO:splink.internals.em_training_session:m probability not trained for unique_id - Exact match on unique_id (comparison vector value: 1). This usually means the comparison level was never observed in the training data.
# INFO:splink.internals.em_training_session:u probability not trained for unique_id - Exact match on unique_id (comparison vector value: 1). This usually means the comparison level was never observed in the training data.
# INFO:splink.internals.settings:
# Your model is not yet fully trained. Missing estimates for:
#     - Title (some u values are not trained, some m values are not trained).
#     - unique_id (some u values are not trained, some m values are not trained).

# %%
# 6. Jalankan probabilistic linkage (EM algorithm)
inference_result = linker.inference.predict()

# 7. Konversi hasil ke pandas DataFrame
df_results = inference_result.as_pandas_dataframe()
# Out:
# INFO:splink.internals.linker_components.inference:Blocking time: 0.00 seconds
# INFO:splink.internals.linker_components.inference:Predict time: 0.10 seconds
# WARNING:splink.internals.linker:
#  -- WARNING --
# You have called predict(), but there are some parameter estimates which have neither been estimated or specified in your settings dictionary.  To produce predictions the following untrained trained parameters will use default values.
# Comparison: 'Title':
#     m values not fully trained
# Comparison: 'Title':
#     u values not fully trained
# Comparison: 'unique_id':
#     m values not fully trained
# Comparison: 'unique_id':
#     u values not fully trained
# The 'probability_two_random_records_match' setting has been set to the default value (0.0001).
# If this is not the desired behaviour, either:
#  - assign a value for `probability_two_random_records_match` in your settings dictionary, or
#  - estimate with the `linker.estimate_probability_two_random_records_match` function.

# %%
df_results
# Out:
#       match_weight  match_probability  unique_id_l  unique_id_r  \
# 0       -70.794023       4.885123e-22            1            2
# 1       -70.794023       4.885123e-22            1            3
# 2       -70.794023       4.885123e-22            2            3
# 3       -70.794023       4.885123e-22            1            4
# 4       -70.794023       4.885123e-22            2            4
# ...            ...                ...          ...          ...
# 4651    -70.794023       4.885123e-22           92           97
# 4652    -70.794023       4.885123e-22           93           97
# 4653    -70.794023       4.885123e-22           94           97
# 4654    -70.794023       4.885123e-22           95           97
# 4655    -70.794023       4.885123e-22           96           97
#
#                                               Authors_l  \
# 0                          I Lewaa, MS Hafez, MA Ismail
# 1                          I Lewaa, MS Hafez, MA Ismail
# 2            M El Abassi, M Amnai, A Choukri, Y Fakhri…
# 3                          I Lewaa, MS Hafez, MA Ismail
# 4            M El Abassi, M Amnai, A Choukri, Y Fakhri…
# ...                                                 ...
# 4651                      X Luo, L Zhang, L Ren, Y Lali
# 4652  S Auzoux, B Ngaba, M Christina, B Heuclin, M R...
# 4653                                A Coppens, V Maquil
# 4654                 A Kato, H Wakabayashi, M Bradford…
# 4655                      UV Albrecht, D Lawin, S Kuhn…
#
#                                        Authors_r  gamma_Authors  \
# 0     M El Abassi, M Amnai, A Choukri, Y Fakhri…              0
# 1                J Yang, K Xian, P Wang, Y Zhang              0
# 2                J Yang, K Xian, P Wang, Y Zhang              0
# 3                        J Yang, S Quan, P Wang…              0
# 4                        J Yang, S Quan, P Wang…              0
# ...                                          ...            ...
# 4651                                     DA Wood              0
# 4652                                     DA Wood              0
# 4653                                     DA Wood              0
# 4654                                     DA Wood              0
# 4655                                     DA Wood              0
#
#                                                 Title_l  \
# 0     Data integration using statistical matching te...
# 1     Data integration using statistical matching te...
# 2     Matching data detection for the integration sy...
# 3     Data integration using statistical matching te...
# 4     Matching data detection for the integration sy...
# ...                                                 ...
# 4651  A dynamic and static data based matching metho...
# 4652  Experimental variables in sugarcane intercropp...
# 4653  Skeletal Data Matching and Merging from Multip...
# 4654  Accurate ground positioning obtained from 3d d...
# 4655  Time bias awareness in ECG-Based multiple sour...
#
#                                                 Title_r  gamma_Title  \
# 0     Matching data detection for the integration sy...            0
# 1     A performance evaluation of correspondence gro...            0
# 2     A performance evaluation of correspondence gro...            0
# 3     Evaluating local geometric feature representat...            0
# 4     Evaluating local geometric feature representat...            0
# ...                                                 ...          ...
# 4651  Solar plus wind country-wide electrical power ...            0
# 4652  Solar plus wind country-wide electrical power ...            0
# 4653  Solar plus wind country-wide electrical power ...            0
# 4654  Solar plus wind country-wide electrical power ...            0
# 4655  Solar plus wind country-wide electrical power ...            0
#
#                                         Source_l  \
# 0                Statistical Journal of the IAOS
# 1                Statistical Journal of the IAOS
# 2                     International Journal of …
# 3                Statistical Journal of the IAOS
# 4                     International Journal of …
# ...                                          ...
# 4651          Robotics and Computer-Integrated …
# 4652                               Data in Brief
# 4653  … 2024, Valencia, Spain, September 15–18 …
# 4654                          IGARSS 2019-2019 …
# 4655                   Advances in Informatics …
#
#                                                Source_r  gamma_Source  \
# 0                            International Journal of …             0
# 1                        IEEE transactions on pattern …             0
# 2                        IEEE transactions on pattern …             0
# 3                                IEEE Transactions on …             0
# 4                                IEEE Transactions on …             0
# ...                                                 ...           ...
# 4651  International Journal of Energy and Environmen...             0
# 4652  International Journal of Energy and Environmen...             0
# 4653  International Journal of Energy and Environmen...             0
# 4654  International Journal of Energy and Environmen...             0
# 4655  International Journal of Energy and Environmen...             0
#
#       gamma_unique_id
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 4651                0
# 4652                0
# 4653                0
# 4654                0
# 4655                0
#
# [4656 rows x 14 columns]

# %%
# prompt: sort the "df_results" dataframe by the "match_probability" column values descending

df_results_sorted = df_results.sort_values(by='match_probability', ascending=False)
df_results_sorted
# Out:
#       match_weight  match_probability  unique_id_l  unique_id_r  \
# 700      12.645623       9.998440e-01           35           38
# 5         2.893353       8.813754e-01            3            4
# 552     -12.610135       1.599196e-04           25           34
# 3098    -21.180426       4.207810e-07           18           80
# 1787    -21.180426       4.207810e-07           18           61
# ...            ...                ...          ...          ...
# 528    -291.368965       1.946264e-88            1           34
# 438    -291.368965       1.946264e-88            4           31
# 454    -291.368965       1.946264e-88           20           31
# 174    -291.368965       1.946264e-88            4           20
# 112    -291.368965       1.946264e-88            8           16
#
#                                        Authors_l  \
# 700             M Graf, L Laskowski, F Papsdorf…
# 5                J Yang, K Xian, P Wang, Y Zhang
# 552                         R D'Alberto, M Raggi
# 3098  C Wüstenhagen, K John, S Langner, M Brede…
# 1787  C Wüstenhagen, K John, S Langner, M Brede…
# ...                                          ...
# 528                 I Lewaa, MS Hafez, MA Ismail
# 438                      J Yang, S Quan, P Wang…
# 454                     W Xue, D Vatsalan, W Hu…
# 174                      J Yang, S Quan, P Wang…
# 112                          B Sun, T Alkhalifah
#
#                                      Authors_r  gamma_Authors  \
# 700   M Graf, L Laskowski, F Papsdorf, F Sold…              1
# 5                      J Yang, S Quan, P Wang…              1
# 552                       R D'Alberto, M Raggi              2
# 3098                 C Wüstenhagen, C Domnick…              1
# 1787                 C Wüstenhagen, C Domnick…              1
# ...                                        ...            ...
# 528                       R D'Alberto, M Raggi              0
# 438            X Peng, H Liu, K Siggers, Z Liu              0
# 454            X Peng, H Liu, K Siggers, Z Liu              0
# 174                   W Xue, D Vatsalan, W Hu…              0
# 112      A Alali, V Kazei, B Sun, T Alkhalifah              0
#
#                                                 Title_l  \
# 700   Frost: Benchmarking and exploring data matchin...
# 5     A performance evaluation of correspondence gro...
# 552   Integrating rather than collecting: statistica...
# 3098  CFD validation using in-vitro MRI velocity dat...
# 1787  CFD validation using in-vitro MRI velocity dat...
# ...                                                 ...
# 528   Data integration using statistical matching te...
# 438   Evaluating local geometric feature representat...
# 454   Sequence data matching and beyond: New privacy...
# 174   Evaluating local geometric feature representat...
# 112   The application of an optimal transport to a p...
#
#                                                 Title_r  gamma_Title  \
# 700   Frost: a platform for benchmarking and explori...            1
# 5     Evaluating local geometric feature representat...            0
# 552   From collection to integration: Non-parametric...            0
# 3098  MRI investigations of internal blade cooling f...            0
# 1787  … Resonance Velocimetry Measurements of Intern...            0
# ...                                                 ...          ...
# 528   From collection to integration: Non-parametric...            0
# 438   Automated box data matching for multi-modal ma...            0
# 454   Automated box data matching for multi-modal ma...            0
# 174   Sequence data matching and beyond: New privacy...            0
# 112   Time-lapse data matching using a recurrent neu...            0
#
#                              Source_l                         Source_r  \
# 700                  arXiv preprint …           arXiv preprint arXiv …
# 5      IEEE transactions on pattern …           IEEE Transactions on …
# 552                Statistical Papers  Statistical Journal of the IAOS
# 3098           Computers in Biology …              … Expo: Power for …
# 1787           Computers in Biology …                     Journal of …
# ...                               ...                              ...
# 528   Statistical Journal of the IAOS  Statistical Journal of the IAOS
# 438            IEEE Transactions on …           IEEE Transactions on …
# 454            IEEE Transactions on …           IEEE Transactions on …
# 174            IEEE Transactions on …           IEEE Transactions on …
# 112                        Geophysics                       Geophysics
#
#       gamma_Source  gamma_unique_id
# 700              1                0
# 5                1                0
# 552              1                0
# 3098             0                0
# 1787             0                0
# ...            ...              ...
# 528              2                0
# 438              2                0
# 454              2                0
# 174              2                0
# 112              2                0
#
# [4656 rows x 14 columns]

# %%
# prompt: sort "df_results" by "unique_id_l" to int asc then by "unique_id_r" to int asc

df_results_sorted_ids = df_results.sort_values(
    by=['unique_id_l', 'unique_id_r']
)
df_results_sorted_ids
# Out:
#       match_weight  match_probability  unique_id_l  unique_id_r  \
# 0       -70.794023       4.885123e-22            1            2
# 1       -70.794023       4.885123e-22            1            3
# 3       -70.794023       4.885123e-22            1            4
# 6       -70.794023       4.885123e-22            1            5
# 10      -70.794023       4.885123e-22            1            6
# ...            ...                ...          ...          ...
# 4558    -70.794023       4.885123e-22           94           96
# 4653    -70.794023       4.885123e-22           94           97
# 4559    -70.794023       4.885123e-22           95           96
# 4654    -70.794023       4.885123e-22           95           97
# 4655    -70.794023       4.885123e-22           96           97
#
#                                Authors_l  \
# 0           I Lewaa, MS Hafez, MA Ismail
# 1           I Lewaa, MS Hafez, MA Ismail
# 3           I Lewaa, MS Hafez, MA Ismail
# 6           I Lewaa, MS Hafez, MA Ismail
# 10          I Lewaa, MS Hafez, MA Ismail
# ...                                  ...
# 4558                 A Coppens, V Maquil
# 4653                 A Coppens, V Maquil
# 4559  A Kato, H Wakabayashi, M Bradford…
# 4654  A Kato, H Wakabayashi, M Bradford…
# 4655       UV Albrecht, D Lawin, S Kuhn…
#
#                                        Authors_r  gamma_Authors  \
# 0     M El Abassi, M Amnai, A Choukri, Y Fakhri…              0
# 1                J Yang, K Xian, P Wang, Y Zhang              0
# 3                        J Yang, S Quan, P Wang…              0
# 6                                  Y Zhu, J Yang              0
# 10                                    LL Sharabi              0
# ...                                          ...            ...
# 4558               UV Albrecht, D Lawin, S Kuhn…              0
# 4653                                     DA Wood              0
# 4559               UV Albrecht, D Lawin, S Kuhn…              0
# 4654                                     DA Wood              0
# 4655                                     DA Wood              0
#
#                                                 Title_l  \
# 0     Data integration using statistical matching te...
# 1     Data integration using statistical matching te...
# 3     Data integration using statistical matching te...
# 6     Data integration using statistical matching te...
# 10    Data integration using statistical matching te...
# ...                                                 ...
# 4558  Skeletal Data Matching and Merging from Multip...
# 4653  Skeletal Data Matching and Merging from Multip...
# 4559  Accurate ground positioning obtained from 3d d...
# 4654  Accurate ground positioning obtained from 3d d...
# 4655  Time bias awareness in ECG-Based multiple sour...
#
#                                                 Title_r  gamma_Title  \
# 0     Matching data detection for the integration sy...            0
# 1     A performance evaluation of correspondence gro...            0
# 3     Evaluating local geometric feature representat...            0
# 6     Automatic data matching for geospatial models:...            0
# 10    Finding love on a first data: Matching algorit...            0
# ...                                                 ...          ...
# 4558  Time bias awareness in ECG-Based multiple sour...            0
# 4653  Solar plus wind country-wide electrical power ...            0
# 4559  Time bias awareness in ECG-Based multiple sour...            0
# 4654  Solar plus wind country-wide electrical power ...            0
# 4655  Solar plus wind country-wide electrical power ...            0
#
#                                         Source_l  \
# 0                Statistical Journal of the IAOS
# 1                Statistical Journal of the IAOS
# 3                Statistical Journal of the IAOS
# 6                Statistical Journal of the IAOS
# 10               Statistical Journal of the IAOS
# ...                                          ...
# 4558  … 2024, Valencia, Spain, September 15–18 …
# 4653  … 2024, Valencia, Spain, September 15–18 …
# 4559                          IGARSS 2019-2019 …
# 4654                          IGARSS 2019-2019 …
# 4655                   Advances in Informatics …
#
#                                                Source_r  gamma_Source  \
# 0                            International Journal of …             0
# 1                        IEEE transactions on pattern …             0
# 3                                IEEE Transactions on …             0
# 6                                         Annals of GIS             0
# 10                          Harvard Data Science Review             0
# ...                                                 ...           ...
# 4558                          Advances in Informatics …             0
# 4653  International Journal of Energy and Environmen...             0
# 4559                          Advances in Informatics …             0
# 4654  International Journal of Energy and Environmen...             0
# 4655  International Journal of Energy and Environmen...             0
#
#       gamma_unique_id
# 0                   0
# 1                   0
# 3                   0
# 6                   0
# 10                  0
# ...               ...
# 4558                0
# 4653                0
# 4559                0
# 4654                0
# 4655                0
#
# [4656 rows x 14 columns]

# %%
# Save the DataFrame to an Excel file
df_results_sorted_ids.to_excel('authors_title_source_sim_res.xlsx', index=False)
